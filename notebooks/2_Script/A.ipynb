# %% [markdown]
# # Simulate user interaction

# %% [markdown]
# ## Load data

# %%
import pandas as pd
df = pd.read_csv('../../data/housing.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# ## Streamlit widgets
#
# https://docs.streamlit.io/develop/api-reference/widgets

# %%
import streamlit as st

# %% [markdown]
# ### Possible values

# %%
df_oce = df['ocean_proximity'].unique()
df_oce
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %% [markdown]
# ### Streamlit widget

# %%
selection = st.selectbox(label="Proximidad al océano: ", options=df_oce)

# %% [markdown]
# ### Masking

# %%
mask = df['ocean_proximity'] == selection
df[mask]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 19067    -122.45     38.28                  20         3306           503.0
# 19068    -122.47     38.29                  14         3732           846.0
# 19069    -122.45     38.27                  25         5024           881.0
# 19077    -122.49     38.27                   8         5092           988.0
# 19104    -122.51     38.17                   8         5875          1115.0
#
# ...

# %% [markdown]
# ## Generate plot

# %%
import plotly.express as px
px.scatter(df, x='median_house_value', y='households', color="population", size_max=15, height=700)
# Out:
# <div>                            <div id="fcec4238-5ea5-4d29-b8e2-86ac3beab5d0" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcec4238-5ea5-4d29-b8e2-86ac3beab5d0")) {                    Plotly.newPlot(                        "fcec4238-5ea5-4d29-b8e2-86ac3beab5d0",                        [{"hovertemplate":"median_house_value=%{x}\u003cbr\u003ehouseholds=%{y}\u003cbr\u003epopulation=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[322,2401,496,558,565,413,1094,1157,1206,1551,910,1504,1098,345,1212,697,793,648,990,690,409,929,1015,853,1006,317,607,1102,1131,395,863,1168,1026,754,1258,570,987,901,689,1377,946,517,462,467,660,718,616,558,423,700,735,1061,1959,1162,701,576,622,728,1074,94,554,86,377,521,392,6
# ...

# %% [markdown]
# ## Create app
#
# 1. Create a file `app.py` in the root folder
# 2. Add the previous code to the file
