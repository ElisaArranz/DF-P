# %% [markdown]
# # Sketch data processing

# %% [markdown]
# ## Load data

# %%
import pandas as pd
df = pd.read_csv('../../data/housing.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %% [markdown]
# ## Filter data

# %% [markdown]
# ### Masking

# %%
df['ocean_proximity'].unique()
mask = df['ocean_proximity'] == 'NEAR OCEAN'
dfr = df[mask]
dfr
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
# ...

# %% [markdown]
# ### Visualization

# %%
import plotly.express as px
px.scatter(dfr, x='median_house_value', y='households', size='housing_median_age', color="population", size_max=15, height=700)
# Out:
# <div>                            <div id="09a2d51f-962c-4fde-a647-91d745b35467" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09a2d51f-962c-4fde-a647-91d745b35467")) {                    Plotly.newPlot(                        "09a2d51f-962c-4fde-a647-91d745b35467",                        [{"hovertemplate":"median_house_value=%{x}\u003cbr\u003ehouseholds=%{y}\u003cbr\u003ehousing_median_age=%{marker.size}\u003cbr\u003epopulation=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1259,1298,1343,1947,1645,1530,1993,1282,1532,1208,841,1244,3546,1382,392,1150,591,891,758,975,837,731,640,883,788,1169,932,1053,990,867,656,950,951,992,1367,235,872,765,908,952,873,911,791,1206,1263,982,1407,1388,829,425,1056,1259,1
# ...
